# %% [markdown]
# __Installation for working crawling with selenium__

# %% [markdown]
# - !pip install selenium
# - !conda install -c conda-forge geckodriver --yes
#
# Create new Terminal and do:
# - apt-get update
# - apt install firefox

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
from utils import *

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

date = datetime.datetime.now().strftime("%Y-%m-%d")
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Get random crops from all around

# %%
get_random_crops_around_nets(zoom_levels=[16], _save_dir="data/inference_random", filename_prefix="2019-11-17", download_how_many=5000)
# Out:
# Obtaining screenshot at coordinates 49.245, -125.145...Screenshot obtained at data/inference_random/2019-11-17_49.245,-125.145_zoom16.png.
# Discard Lat 50.875 and Long -127.978 as its too close to 50.855 and -128.005
# Obtaining screenshot at coordinates 51.483, -127.667...Screenshot obtained at data/inference_random/2019-11-17_51.483,-127.667_zoom16.png.
# Discard Lat 48.719 and Long -127.613 as its too close to 48.739 and -127.607
# Obtaining screenshot at coordinates 51.594, -123.494...Screenshot obtained at data/inference_random/2019-11-17_51.594,-123.494_zoom16.png.
# Obtaining screenshot at coordinates 51.025, -124.595...Screenshot obtained at data/inference_random/2019-11-17_51.025,-124.595_zoom16.png.
# Discard Lat 49.636 and Long -127.152 as its too close to 49.650 and -127.144
# Obtaining screenshot at coordinates 51.929, -126.836...Screenshot obtained at data/inference_random/2019-11-17_51.929,-126.836_zoom16.png.
# Obtaining screenshot at coordinates 51.119, -125.106...Screenshot obtained at data/inference_random/2019-11-17_51.119,-125.106_zoom16.png.
# Discard Lat 49.003 and Long -123.635 as its too close to 48.977 and -123.602
# Discard Lat 48.610 and Long -124.359 as its too close to 48.610 and -124.349
# Obtaining screenshot at coordinates 51.406, -126.309...Screenshot obtained at data/inference_random/2019-11-17_51.406,-126.309_zoom16.png.
# Obtaining screenshot at coordinates 51.902, -123.935...Screenshot obtained at data/inference_random/2019-11-17_51.902,-123.935_zoom16.png.
# Obtaining screenshot at coordinates 52.7, -123.826...Screenshot obtained at data/inference_random/2019-11-17_52.7,-123.826_zoom16.png.
# Discard Lat 50.905 and Long -124.589 as its too close to 50.923 and -124.575
# Obtaining screenshot at coordinates 51.905, -126.142...Screenshot obtained at data/inference_random/2019-11-17_51.905,-126.142_zoom16.png.
# Obtaining screenshot at coordinates 49.187, -125.671...Screenshot obtained at data/inference_random/2019-11-17_49.187,-125.671_zoom16.png.
# Discard Lat 50.280 and Long -125.624 as its too close to 50.288 and -125.633
# Discard Lat 48.589 and Long -127.649 as its too close to 48.616 and -127.622
# Obtaining screenshot at coordinates 50.546, -128.149...Screenshot obtained at data/inference_random/2019-11-17_50.546,-128.149_zoom16.png.
# Discard Lat 50.392 and Long -125.453 as its too close to 50.404 and -125.439
# Obtaining screenshot at coordinates 50.934, -127.209...Screenshot obtained at data/inference_random/2019-11-17_50.934,-127.209_zoom16.png.
# Obtaining screenshot at coordinates 52.263, -123.62...Screenshot obtained at data/inference_random/2019-11-17_52.263,-123.62_zoom16.png.
# Obtaining screenshot at coordinates 51.346, -128.391...Screenshot obtained at data/inference_random/2019-11-17_51.346,-128.391_zoom16.png.
# Obtaining screenshot at coordinates 51.843, -125.462...Screenshot obtained at data/inference_random/2019-11-17_51.843,-125.462_zoom16.png.
# Discard Lat 49.225 and Long -126.209 as its too close to 49.242 and -126.175
# Obtaining screenshot at coordinates 49.268, -125.701...Screenshot obtained at data/inference_random/2019-11-17_49.268,-125.701_zoom16.png.
# Discard Lat 50.342 and Long -124.780 as its too close to 50.362 and -124.794
# Obtaining screenshot at coordinates 49.534, -125.692...Screenshot obtained at data/inference_random/2019-11-17_49.534,-125.692_zoom16.png.
# Obtaining screenshot at coordinates 52.663, -128.252...Screenshot obtained at data/inference_random/2019-11-17_52.663,-128.252_zoom16.png.
# Obtaining screenshot at coordinates 49.823, -126.349...Screenshot obtained at data/inference_random/2019-11-17_49.823,-126.349_zoom16.png.
# Obtaining screenshot at coordinates 50.246, -125.765...Screenshot obtained at data/inference_random/2019-11-17_50.246,-125.765_zoom16.png.
# Obtaining screenshot at coordinates 50.94, -126.411...Screenshot obtained at data/inference_random/2019-11-17_50.94,-126.411_zoom16.png.
# Obtaining screenshot at coordinates 52.627, -127.68...Screenshot obtained at data/inference_random/2019-11-17_52.627,-127.68_zoom16.png.
# Obtaining screenshot at coordinates 51.462, -127.251...Screenshot obtained at data/inference_random/2019-11-17_51.462,-127.251_zoom16.png.
# Obtaining screenshot at coordinates 50.975, -124.667...Screenshot obtained at data/inference_random/2019-11-17_50.975,-124.667_zoom16.png.
# Obtaining screenshot at coordinates 52.27, -127.638...Screenshot obtained at data/inference_random/2019-11-17_52.27,-127.638_zoom16.png.
# Discard Lat 50.532 and Long -128.027 as its too close to 50.522 and -128.009
# Obtaining screenshot at coordinates 52.795, -124.705...Screenshot obtained at data/inference_random/2019-11-17_52.795,-124.705_zoom16.png.
# Discard Lat 50.316 and Long -125.625 as its too close to 50.342 and -125.619
# Discard Lat 48.677 and Long -126.797 as its too close to 48.654 and -126.792
# Obtaining screenshot at coordinates 51.896, -124.977...Screenshot obtained at data/inference_random/2019-11-17_51.896,-124.977_zoom16.png.
# Obtaining screenshot at coordinates 51.736, -128.412...Screenshot obtained at data/inference_random/2019-11-17_51.736,-128.412_zoom16.png.
# Discard Lat 49.087 and Long -124.999 as its too close to 49.100 and -124.971
# Obtaining screenshot at coordinates 49.094, -127.554...Screenshot obtained at data/inference_random/2019-11-17_49.094,-127.554_zoom16.png.
# Obtaining screenshot at coordinates 51.967, -127.901...Screenshot obtained at data/inference_random/2019-11-17_51.967,-127.901_zoom16.png.
# Obtaining screenshot at coordinates 49.34, -128.328...Screenshot obtained at data/inference_random/2019-11-17_49.34,-128.328_zoom16.png.
# Discard Lat 50.456 and Long -125.282 as its too close to 50.468 and -125.260
# Discard Lat 50.212 and Long -124.127 as its too close to 50.221 and -124.144
# Discard Lat 48.927 and Long -123.882 as its too close to 48.953 and -123.916
# Obtaining screenshot at coordinates 49.148, -126.449...Screenshot obtained at data/inference_random/2019-11-17_49.148,-126.449_zoom16.png.
# Obtaining screenshot at coordinates 50.731, -124.278...Screenshot obtained at data/inference_random/2019-11-17_50.731,-124.278_zoom16.png.
# Discard Lat 50.372 and Long -126.282 as its too close to 50.393 and -126.271
# Discard Lat 49.545 and Long -127.928 as its too close to 49.554 and -127.928
# Discard Lat 49.131 and Long -127.233 as its too close to 49.105 and -127.260
# Obtaining screenshot at coordinates 51.539, -124.328...Screenshot obtained at data/inference_random/2019-11-17_51.539,-124.328_zoom16.png.
# Obtaining screenshot at coordinates 51.735, -126.947...Screenshot obtained at data/inference_random/2019-11-17_51.735,-126.947_zoom16.png.
# Discard Lat 49.136 and Long -126.554 as its too close to 49.121 and -126.554
# Obtaining screenshot at coordinates 51.376, -125.296...Screenshot obtained at data/inference_random/2019-11-17_51.376,-125.296_zoom16.png.
# Obtaining screenshot at coordinates 51.531, -128.379...Screenshot obtained at data/inference_random/2019-11-17_51.531,-128.379_zoom16.png.
# Obtaining screenshot at coordinates 51.628, -123.938...Screenshot obtained at data/inference_random/2019-11-17_51.628,-123.938_zoom16.png.
# Discard Lat 50.658 and Long -125.677 as its too close to 50.652 and -125.694
# Obtaining screenshot at coordinates 52.279, -128.508...Screenshot obtained at data/inference_random/2019-11-17_52.279,-128.508_zoom16.png.
# Obtaining screenshot at coordinates 52.739, -127.99...Screenshot obtained at data/inference_random/2019-11-17_52.739,-127.99_zoom16.png.
# Discard Lat 50.920 and Long -126.206 as its too close to 50.907 and -126.232
# Obtaining screenshot at coordinates 50.32, -124.724...Screenshot obtained at data/inference_random/2019-11-17_50.32,-124.724_zoom16.png.
# Obtaining screenshot at coordinates 51.446, -126.049...Screenshot obtained at data/inference_random/2019-11-17_51.446,-126.049_zoom16.png.
# Obtaining screenshot at coordinates 52.753, -124.712...Screenshot obtained at data/inference_random/2019-11-17_52.753,-124.712_zoom16.png.
# Discard Lat 50.290 and Long -126.385 as its too close to 50.267 and -126.358
# Obtaining screenshot at coordinates 51.029, -128.31...Screenshot obtained at data/inference_random/2019-11-17_51.029,-128.31_zoom16.png.
# Obtaining screenshot at coordinates 51.427, -126.533...Screenshot obtained at data/inference_random/2019-11-17_51.427,-126.533_zoom16.png.
# Obtaining screenshot at coordinates 51.001, -126.13...Screenshot obtained at data/inference_random/2019-11-17_51.001,-126.13_zoom16.png.
# Discard Lat 50.191 and Long -125.216 as its too close to 50.208 and -125.198
# Obtaining screenshot at coordinates 51.3, -124.667...Screenshot obtained at data/inference_random/2019-11-17_51.3,-124.667_zoom16.png.
# Obtaining screenshot at coordinates 52.039, -123.751...Screenshot obtained at data/inference_random/2019-11-17_52.039,-123.751_zoom16.png.
# Obtaining screenshot at coordinates 49.055, -127.749...Screenshot obtained at data/inference_random/2019-11-17_49.055,-127.749_zoom16.png.
# Obtaining screenshot at coordinates 52.36, -125.068...Screenshot obtained at data/inference_random/2019-11-17_52.36,-125.068_zoom16.png.
# Discard Lat 50.830 and Long -126.190 as its too close to 50.855 and -126.158
# Obtaining screenshot at coordinates 50.221, -126.663...Screenshot obtained at data/inference_random/2019-11-17_50.221,-126.663_zoom16.png.
# Obtaining screenshot at coordinates 51.141, -123.54...Screenshot obtained at data/inference_random/2019-11-17_51.141,-123.54_zoom16.png.
# Discard Lat 50.648 and Long -127.772 as its too close to 50.670 and -127.788
# Discard Lat 49.623 and Long -124.025 as its too close to 49.625 and -124.022
# Obtaining screenshot at coordinates 52.069, -125.079...Screenshot obtained at data/inference_random/2019-11-17_52.069,-125.079_zoom16.png.
# Discard Lat 49.740 and Long -127.151 as its too close to 49.736 and -127.127
# Obtaining screenshot at coordinates 51.313, -125.833...Screenshot obtained at data/inference_random/2019-11-17_51.313,-125.833_zoom16.png.
# Obtaining screenshot at coordinates 51.376, -123.698...Screenshot obtained at data/inference_random/2019-11-17_51.376,-123.698_zoom16.png.
# Obtaining screenshot at coordinates 51.104, -124.45...Screenshot obtained at data/inference_random/2019-11-17_51.104,-124.45_zoom16.png.
# Obtaining screenshot at coordinates 49.416, -125.361...Screenshot obtained at data/inference_random/2019-11-17_49.416,-125.361_zoom16.png.
# Obtaining screenshot at coordinates 50.768, -123.712...Screenshot obtained at data/inference_random/2019-11-17_50.768,-123.712_zoom16.png.
# Obtaining screenshot at coordinates 52.686, -123.636...Screenshot obtained at data/inference_random/2019-11-17_52.686,-123.636_zoom16.png.
# Obtaining screenshot at coordinates 49.317, -125.462...Screenshot obtained at data/inference_random/2019-11-17_49.317,-125.462_zoom16.png.
# Discard Lat 50.186 and Long -126.834 as its too close to 50.194 and -126.811
# Discard Lat 49.543 and Long -126.506 as its too close to 49.545 and -126.508
# Obtaining screenshot at coordinates 52.386, -126.535...Screenshot obtained at data/inference_random/2019-11-17_52.386,-126.535_zoom16.png.
# Obtaining screenshot at coordinates 50.302, -128.03...Screenshot obtained at data/inference_random/2019-11-17_50.302,-128.03_zoom16.png.
# Obtaining screenshot at coordinates 48.702, -128.452...Screenshot obtained at data/inference_random/2019-11-17_48.702,-128.452_zoom16.png.
# Obtaining screenshot at coordinates 52.191, -128.019...Screenshot obtained at data/inference_random/2019-11-17_52.191,-128.019_zoom16.png.
# Discard Lat 48.617 and Long -126.838 as its too close to 48.596 and -126.823
# Obtaining screenshot at coordinates 48.859, -128.357...Screenshot obtained at data/inference_random/2019-11-17_48.859,-128.357_zoom16.png.
# Discard Lat 49.553 and Long -125.190 as its too close to 49.558 and -125.215
# Obtaining screenshot at coordinates 49.377, -127.035...Screenshot obtained at data/inference_random/2019-11-17_49.377,-127.035_zoom16.png.
# Obtaining screenshot at coordinates 50.747, -128.511...Screenshot obtained at data/inference_random/2019-11-17_50.747,-128.511_zoom16.png.
# Discard Lat 48.735 and Long -125.810 as its too close to 48.751 and -125.777
# Discard Lat 48.785 and Long -125.051 as its too close to 48.787 and -125.058
# Obtaining screenshot at coordinates 49.61, -128.448...Screenshot obtained at data/inference_random/2019-11-17_49.61,-128.448_zoom16.png.
# Discard Lat 48.792 and Long -127.866 as its too close to 48.809 and -127.840
# Obtaining screenshot at coordinates 51.266, -125.06...Screenshot obtained at data/inference_random/2019-11-17_51.266,-125.06_zoom16.png.
# Obtaining screenshot at coordinates 52.07, -124.325...Screenshot obtained at data/inference_random/2019-11-17_52.07,-124.325_zoom16.png.
# Discard Lat 48.975 and Long -126.794 as its too close to 48.988 and -126.795
# Obtaining screenshot at coordinates 52.078, -126.905...Screenshot obtained at data/inference_random/2019-11-17_52.078,-126.905_zoom16.png.
# Obtaining screenshot at coordinates 48.822, -124.786...Screenshot obtained at data/inference_random/2019-11-17_48.822,-124.786_zoom16.png.
# Obtaining screenshot at coordinates 50.771, -124.417...Screenshot obtained at data/inference_random/2019-11-17_50.771,-124.417_zoom16.png.
# Discard Lat 50.190 and Long -127.517 as its too close to 50.204 and -127.516
# Obtaining screenshot at coordinates 50.947, -127.178...Screenshot obtained at data/inference_random/2019-11-17_50.947,-127.178_zoom16.png.
# Obtaining screenshot at coordinates 50.539, -126.903...Screenshot obtained at data/inference_random/2019-11-17_50.539,-126.903_zoom16.png.
# Obtaining screenshot at coordinates 49.635, -124.368...Screenshot obtained at data/inference_random/2019-11-17_49.635,-124.368_zoom16.png.
# Discard Lat 50.656 and Long -124.836 as its too close to 50.665 and -124.864
# Discard Lat 49.179 and Long -126.275 as its too close to 49.170 and -126.249
# Obtaining screenshot at coordinates 52.45, -126.788...Screenshot obtained at data/inference_random/2019-11-17_52.45,-126.788_zoom16.png.
# Obtaining screenshot at coordinates 49.668, -124.799...Screenshot obtained at data/inference_random/2019-11-17_49.668,-124.799_zoom16.png.
# Discard Lat 50.742 and Long -127.087 as its too close to 50.745 and -127.108
# Discard Lat 48.883 and Long -124.026 as its too close to 48.901 and -123.997
# Obtaining screenshot at coordinates 51.537, -125.201...Screenshot obtained at data/inference_random/2019-11-17_51.537,-125.201_zoom16.png.
# Obtaining screenshot at coordinates 50.318, -128.518...Screenshot obtained at data/inference_random/2019-11-17_50.318,-128.518_zoom16.png.
# Discard Lat 50.293 and Long -124.769 as its too close to 50.268 and -124.765
# Discard Lat 50.289 and Long -125.296 as its too close to 50.309 and -125.317
# Obtaining screenshot at coordinates 48.796, -127.171...Screenshot obtained at data/inference_random/2019-11-17_48.796,-127.171_zoom16.png.
# Obtaining screenshot at coordinates 52.41, -127.325...Screenshot obtained at data/inference_random/2019-11-17_52.41,-127.325_zoom16.png.
# Obtaining screenshot at coordinates 48.688, -125.845...Screenshot obtained at data/inference_random/2019-11-17_48.688,-125.845_zoom16.png.
# Discard Lat 50.334 and Long -123.665 as its too close to 50.343 and -123.669
# Obtaining screenshot at coordinates 50.49, -128.063...Screenshot obtained at data/inference_random/2019-11-17_50.49,-128.063_zoom16.png.
# Obtaining screenshot at coordinates 49.801, -127.203...Screenshot obtained at data/inference_random/2019-11-17_49.801,-127.203_zoom16.png.
# Discard Lat 49.936 and Long -124.140 as its too close to 49.914 and -124.160
# Discard Lat 48.798 and Long -126.979 as its too close to 48.823 and -126.975
# Discard Lat 48.701 and Long -123.551 as its too close to 48.703 and -123.543
# Obtaining screenshot at coordinates 52.664, -124.506...Screenshot obtained at data/inference_random/2019-11-17_52.664,-124.506_zoom16.png.
# Obtaining screenshot at coordinates 51.137, -123.857...Screenshot obtained at data/inference_random/2019-11-17_51.137,-123.857_zoom16.png.
# Discard Lat 49.820 and Long -127.032 as its too close to 49.846 and -127.007
# Obtaining screenshot at coordinates 49.162, -126.433...Screenshot obtained at data/inference_random/2019-11-17_49.162,-126.433_zoom16.png.
# Obtaining screenshot at coordinates 51.996, -126.531...Screenshot obtained at data/inference_random/2019-11-17_51.996,-126.531_zoom16.png.
# Obtaining screenshot at coordinates 51.435, -125.502...Screenshot obtained at data/inference_random/2019-11-17_51.435,-125.502_zoom16.png.
# Obtaining screenshot at coordinates 50.05, -125.993...Screenshot obtained at data/inference_random/2019-11-17_50.05,-125.993_zoom16.png.
# Obtaining screenshot at coordinates 50.415, -128.346...Screenshot obtained at data/inference_random/2019-11-17_50.415,-128.346_zoom16.png.
# Obtaining screenshot at coordinates 50.895, -127.237...Screenshot obtained at data/inference_random/2019-11-17_50.895,-127.237_zoom16.png.
# Obtaining screenshot at coordinates 51.721, -124.964...Screenshot obtained at data/inference_random/2019-11-17_51.721,-124.964_zoom16.png.
# Obtaining screenshot at coordinates 52.297, -126.825...Screenshot obtained at data/inference_random/2019-11-17_52.297,-126.825_zoom16.png.
# Discard Lat 50.360 and Long -126.608 as its too close to 50.360 and -126.616
# Discard Lat 50.333 and Long -127.189 as its too close to 50.350 and -127.217
# Discard Lat 49.847 and Long -124.227 as its too close to 49.855 and -124.227
# Discard Lat 49.847 and Long -124.227 as its too close to 49.844 and -124.227
# Obtaining screenshot at coordinates 52.534, -126.74...Screenshot obtained at data/inference_random/2019-11-17_52.534,-126.74_zoom16.png.
# Obtaining screenshot at coordinates 49.336, -126.443...Screenshot obtained at data/inference_random/2019-11-17_49.336,-126.443_zoom16.png.
# Obtaining screenshot at coordinates 49.583, -125.273...Screenshot obtained at data/inference_random/2019-11-17_49.583,-125.273_zoom16.png.
# Discard Lat 50.608 and Long -125.855 as its too close to 50.617 and -125.831
# Discard Lat 49.429 and Long -124.063 as its too close to 49.427 and -124.032
# Obtaining screenshot at coordinates 50.236, -123.727...Screenshot obtained at data/inference_random/2019-11-17_50.236,-123.727_zoom16.png.
# Obtaining screenshot at coordinates 50.753, -125.211...Screenshot obtained at data/inference_random/2019-11-17_50.753,-125.211_zoom16.png.
# Obtaining screenshot at coordinates 50.695, -125.684...Screenshot obtained at data/inference_random/2019-11-17_50.695,-125.684_zoom16.png.
# Obtaining screenshot at coordinates 51.763, -128.463...Screenshot obtained at data/inference_random/2019-11-17_51.763,-128.463_zoom16.png.
# Discard Lat 48.740 and Long -125.703 as its too close to 48.752 and -125.728
# Obtaining screenshot at coordinates 50.389, -123.629...Screenshot obtained at data/inference_random/2019-11-17_50.389,-123.629_zoom16.png.
# Discard Lat 52.166 and Long -127.990 as its too close to 52.191 and -128.019
# Obtaining screenshot at coordinates 49.109, -123.954...Screenshot obtained at data/inference_random/2019-11-17_49.109,-123.954_zoom16.png.
# Discard Lat 49.012 and Long -124.723 as its too close to 49.005 and -124.696
# Obtaining screenshot at coordinates 49.973, -126.379...Screenshot obtained at data/inference_random/2019-11-17_49.973,-126.379_zoom16.png.
# Discard Lat 49.113 and Long -124.031 as its too close to 49.134 and -124.022
# Discard Lat 48.983 and Long -126.926 as its too close to 48.984 and -126.936
# Discard Lat 49.869 and Long -126.670 as its too close to 49.844 and -126.674
# Discard Lat 50.325 and Long -126.258 as its too close to 50.304 and -126.292
# Obtaining screenshot at coordinates 52.11, -126.006...Screenshot obtained at data/inference_random/2019-11-17_52.11,-126.006_zoom16.png.
# Obtaining screenshot at coordinates 49.589, -126.386...Screenshot obtained at data/inference_random/2019-11-17_49.589,-126.386_zoom16.png.
# Obtaining screenshot at coordinates 49.073, -125.179...Screenshot obtained at data/inference_random/2019-11-17_49.073,-125.179_zoom16.png.
# Obtaining screenshot at coordinates 49.276, -127.786...Screenshot obtained at data/inference_random/2019-11-17_49.276,-127.786_zoom16.png.
# Obtaining screenshot at coordinates 52.309, -126.161...Screenshot obtained at data/inference_random/2019-11-17_52.309,-126.161_zoom16.png.
# Obtaining screenshot at coordinates 52.732, -125.139...Screenshot obtained at data/inference_random/2019-11-17_52.732,-125.139_zoom16.png.
# Obtaining screenshot at coordinates 51.393, -127.979...Screenshot obtained at data/inference_random/2019-11-17_51.393,-127.979_zoom16.png.
# Obtaining screenshot at coordinates 49.115, -127.829...Screenshot obtained at data/inference_random/2019-11-17_49.115,-127.829_zoom16.png.
# Discard Lat 50.730 and Long -124.269 as its too close to 50.731 and -124.278
# Obtaining screenshot at coordinates 50.836, -125.558...Screenshot obtained at data/inference_random/2019-11-17_50.836,-125.558_zoom16.png.
# Obtaining screenshot at coordinates 51.43, -123.864...Screenshot obtained at data/inference_random/2019-11-17_51.43,-123.864_zoom16.png.
# Obtaining screenshot at coordinates 51.196, -123.814...Screenshot obtained at data/inference_random/2019-11-17_51.196,-123.814_zoom16.png.
# Obtaining screenshot at coordinates 52.014, -124.781...Screenshot obtained at data/inference_random/2019-11-17_52.014,-124.781_zoom16.png.
# Discard Lat 48.687 and Long -126.747 as its too close to 48.679 and -126.735
# Discard Lat 50.637 and Long -125.447 as its too close to 50.634 and -125.457
# Obtaining screenshot at coordinates 51.48, -127.309...Screenshot obtained at data/inference_random/2019-11-17_51.48,-127.309_zoom16.png.
# Obtaining screenshot at coordinates 52.609, -128.278...Screenshot obtained at data/inference_random/2019-11-17_52.609,-128.278_zoom16.png.
# Obtaining screenshot at coordinates 51.508, -124.452...Screenshot obtained at data/inference_random/2019-11-17_51.508,-124.452_zoom16.png.
# Obtaining screenshot at coordinates 51.354, -124.097...Screenshot obtained at data/inference_random/2019-11-17_51.354,-124.097_zoom16.png.
# Obtaining screenshot at coordinates 52.709, -125.977...Screenshot obtained at data/inference_random/2019-11-17_52.709,-125.977_zoom16.png.
# Obtaining screenshot at coordinates 52.795, -125.643...Screenshot obtained at data/inference_random/2019-11-17_52.795,-125.643_zoom16.png.
# Obtaining screenshot at coordinates 51.185, -123.802...Screenshot obtained at data/inference_random/2019-11-17_51.185,-123.802_zoom16.png.
# Discard Lat 50.881 and Long -126.738 as its too close to 50.878 and -126.755
# Discard Lat 50.281 and Long -123.591 as its too close to 50.277 and -123.566
# Obtaining screenshot at coordinates 50.373, -128.12...Screenshot obtained at data/inference_random/2019-11-17_50.373,-128.12_zoom16.png.
# Obtaining screenshot at coordinates 52.057, -124.939...Screenshot obtained at data/inference_random/2019-11-17_52.057,-124.939_zoom16.png.
# Obtaining screenshot at coordinates 52.114, -126.833...Screenshot obtained at data/inference_random/2019-11-17_52.114,-126.833_zoom16.png.
# Obtaining screenshot at coordinates 49.062, -124.63...Screenshot obtained at data/inference_random/2019-11-17_49.062,-124.63_zoom16.png.
# Discard Lat 49.747 and Long -125.248 as its too close to 49.737 and -125.283
# Obtaining screenshot at coordinates 51.457, -124.156...Screenshot obtained at data/inference_random/2019-11-17_51.457,-124.156_zoom16.png.
# Discard Lat 49.106 and Long -124.917 as its too close to 49.099 and -124.921
# Discard Lat 49.808 and Long -123.925 as its too close to 49.819 and -123.954
# Obtaining screenshot at coordinates 51.212, -123.761...Screenshot obtained at data/inference_random/2019-11-17_51.212,-123.761_zoom16.png.
# Obtaining screenshot at coordinates 52.197, -125.285...Screenshot obtained at data/inference_random/2019-11-17_52.197,-125.285_zoom16.png.
# Obtaining screenshot at coordinates 51.058, -126.113...Screenshot obtained at data/inference_random/2019-11-17_51.058,-126.113_zoom16.png.
# Discard Lat 49.852 and Long -126.611 as its too close to 49.852 and -126.591
# Obtaining screenshot at coordinates 50.36, -128.093...Screenshot obtained at data/inference_random/2019-11-17_50.36,-128.093_zoom16.png.
# Discard Lat 50.927 and Long -125.606 as its too close to 50.929 and -125.606
# Obtaining screenshot at coordinates 48.875, -128.199...Screenshot obtained at data/inference_random/2019-11-17_48.875,-128.199_zoom16.png.
# Obtaining screenshot at coordinates 52.02, -127.116...Screenshot obtained at data/inference_random/2019-11-17_52.02,-127.116_zoom16.png.
# Obtaining screenshot at coordinates 49.076, -125.973...Screenshot obtained at data/inference_random/2019-11-17_49.076,-125.973_zoom16.png.
# Obtaining screenshot at coordinates 49.49, -128.012...Screenshot obtained at data/inference_random/2019-11-17_49.49,-128.012_zoom16.png.
# Obtaining screenshot at coordinates 49.847, -124.411...Screenshot obtained at data/inference_random/2019-11-17_49.847,-124.411_zoom16.png.
# Obtaining screenshot at coordinates 49.627, -123.912...Screenshot obtained at data/inference_random/2019-11-17_49.627,-123.912_zoom16.png.
# Discard Lat 50.719 and Long -127.005 as its too close to 50.727 and -127.004
# Discard Lat 50.334 and Long -127.833 as its too close to 50.329 and -127.846
# Discard Lat 52.657 and Long -124.484 as its too close to 52.664 and -124.506
# Obtaining screenshot at coordinates 52.559, -125.535...Screenshot obtained at data/inference_random/2019-11-17_52.559,-125.535_zoom16.png.
# Obtaining screenshot at coordinates 51.311, -127.596...Screenshot obtained at data/inference_random/2019-11-17_51.311,-127.596_zoom16.png.
# Obtaining screenshot at coordinates 49.001, -125.71...Screenshot obtained at data/inference_random/2019-11-17_49.001,-125.71_zoom16.png.
# Obtaining screenshot at coordinates 49.979, -124.812...Screenshot obtained at data/inference_random/2019-11-17_49.979,-124.812_zoom16.png.
# Obtaining screenshot at coordinates 52.563, -123.73...Screenshot obtained at data/inference_random/2019-11-17_52.563,-123.73_zoom16.png.
# Discard Lat 49.893 and Long -125.845 as its too close to 49.918 and -125.876
# Obtaining screenshot at coordinates 51.579, -125.207...Screenshot obtained at data/inference_random/2019-11-17_51.579,-125.207_zoom16.png.
# Discard Lat 49.576 and Long -126.102 as its too close to 49.597 and -126.105
# Obtaining screenshot at coordinates 52.722, -125.883...Screenshot obtained at data/inference_random/2019-11-17_52.722,-125.883_zoom16.png.
# Obtaining screenshot at coordinates 52.72, -124.56...Screenshot obtained at data/inference_random/2019-11-17_52.72,-124.56_zoom16.png.
# Obtaining screenshot at coordinates 49.734, -126.707...Screenshot obtained at data/inference_random/2019-11-17_49.734,-126.707_zoom16.png.
# Obtaining screenshot at coordinates 52.616, -126.187...Screenshot obtained at data/inference_random/2019-11-17_52.616,-126.187_zoom16.png.
# Obtaining screenshot at coordinates 50.028, -128.303...Screenshot obtained at data/inference_random/2019-11-17_50.028,-128.303_zoom16.png.
# Discard Lat 49.844 and Long -126.685 as its too close to 49.844 and -126.674
# Obtaining screenshot at coordinates 52.443, -124.639...Screenshot obtained at data/inference_random/2019-11-17_52.443,-124.639_zoom16.png.
# Obtaining screenshot at coordinates 51.959, -125.829...Screenshot obtained at data/inference_random/2019-11-17_51.959,-125.829_zoom16.png.
# Discard Lat 49.615 and Long -124.365 as its too close to 49.635 and -124.368
# Obtaining screenshot at coordinates 49.923, -124.217...Screenshot obtained at data/inference_random/2019-11-17_49.923,-124.217_zoom16.png.
# Obtaining screenshot at coordinates 50.913, -126.786...Screenshot obtained at data/inference_random/2019-11-17_50.913,-126.786_zoom16.png.
# Discard Lat 48.668 and Long -126.720 as its too close to 48.651 and -126.737
# Discard Lat 50.471 and Long -124.224 as its too close to 50.459 and -124.252
# Discard Lat 50.292 and Long -124.441 as its too close to 50.293 and -124.449
# Obtaining screenshot at coordinates 51.264, -127.78...Screenshot obtained at data/inference_random/2019-11-17_51.264,-127.78_zoom16.png.
# Obtaining screenshot at coordinates 52.531, -125.011...Screenshot obtained at data/inference_random/2019-11-17_52.531,-125.011_zoom16.png.
# Obtaining screenshot at coordinates 49.054, -128.517...Screenshot obtained at data/inference_random/2019-11-17_49.054,-128.517_zoom16.png.
# Obtaining screenshot at coordinates 51.496, -124.804...Screenshot obtained at data/inference_random/2019-11-17_51.496,-124.804_zoom16.png.
# Discard Lat 48.772 and Long -127.870 as its too close to 48.754 and -127.888
# Obtaining screenshot at coordinates 51.031, -128.14...Screenshot obtained at data/inference_random/2019-11-17_51.031,-128.14_zoom16.png.
# Obtaining screenshot at coordinates 52.06, -125.025...Screenshot obtained at data/inference_random/2019-11-17_52.06,-125.025_zoom16.png.
# Obtaining screenshot at coordinates 49.924, -127.26...Screenshot obtained at data/inference_random/2019-11-17_49.924,-127.26_zoom16.png.
# Discard Lat 50.696 and Long -124.294 as its too close to 50.693 and -124.294
# Obtaining screenshot at coordinates 52.06, -127.272...Screenshot obtained at data/inference_random/2019-11-17_52.06,-127.272_zoom16.png.
# Discard Lat 48.700 and Long -126.592 as its too close to 48.723 and -126.625
# Obtaining screenshot at coordinates 51.522, -128.292...Screenshot obtained at data/inference_random/2019-11-17_51.522,-128.292_zoom16.png.
# Obtaining screenshot at coordinates 51.747, -127.522...Screenshot obtained at data/inference_random/2019-11-17_51.747,-127.522_zoom16.png.
# Obtaining screenshot at coordinates 52.465, -125.653...Screenshot obtained at data/inference_random/2019-11-17_52.465,-125.653_zoom16.png.
# Obtaining screenshot at coordinates 52.703, -127.159...Screenshot obtained at data/inference_random/2019-11-17_52.703,-127.159_zoom16.png.
# Obtaining screenshot at coordinates 52.069, -127.087...Screenshot obtained at data/inference_random/2019-11-17_52.069,-127.087_zoom16.png.
# Obtaining screenshot at coordinates 49.509, -128.285...Screenshot obtained at data/inference_random/2019-11-17_49.509,-128.285_zoom16.png.
# Discard Lat 49.969 and Long -125.759 as its too close to 49.949 and -125.771
# Obtaining screenshot at coordinates 52.174, -124.548...Screenshot obtained at data/inference_random/2019-11-17_52.174,-124.548_zoom16.png.
# Obtaining screenshot at coordinates 49.071, -127.433...Screenshot obtained at data/inference_random/2019-11-17_49.071,-127.433_zoom16.png.
# Obtaining screenshot at coordinates 50.277, -126.767...Screenshot obtained at data/inference_random/2019-11-17_50.277,-126.767_zoom16.png.
# Discard Lat 49.614 and Long -126.047 as its too close to 49.607 and -126.077
# Discard Lat 50.610 and Long -125.293 as its too close to 50.629 and -125.288
# Obtaining screenshot at coordinates 52.18, -125.074...Screenshot obtained at data/inference_random/2019-11-17_52.18,-125.074_zoom16.png.
# Obtaining screenshot at coordinates 51.475, -125.466...Screenshot obtained at data/inference_random/2019-11-17_51.475,-125.466_zoom16.png.
# Obtaining screenshot at coordinates 51.857, -125.512...Screenshot obtained at data/inference_random/2019-11-17_51.857,-125.512_zoom16.png.
# Obtaining screenshot at coordinates 52.686, -126.987...Screenshot obtained at data/inference_random/2019-11-17_52.686,-126.987_zoom16.png.
# Obtaining screenshot at coordinates 51.613, -126.308...Screenshot obtained at data/inference_random/2019-11-17_51.613,-126.308_zoom16.png.
# Discard Lat 50.580 and Long -125.931 as its too close to 50.582 and -125.939
# Obtaining screenshot at coordinates 51.666, -128.329...Screenshot obtained at data/inference_random/2019-11-17_51.666,-128.329_zoom16.png.
# Obtaining screenshot at coordinates 51.153, -127.009...Screenshot obtained at data/inference_random/2019-11-17_51.153,-127.009_zoom16.png.
# Obtaining screenshot at coordinates 49.428, -127.445...Screenshot obtained at data/inference_random/2019-11-17_49.428,-127.445_zoom16.png.
# Obtaining screenshot at coordinates 51.844, -124.442...Screenshot obtained at data/inference_random/2019-11-17_51.844,-124.442_zoom16.png.
# Obtaining screenshot at coordinates 51.912, -126.716...Screenshot obtained at data/inference_random/2019-11-17_51.912,-126.716_zoom16.png.
# Discard Lat 50.113 and Long -124.652 as its too close to 50.102 and -124.647
# Obtaining screenshot at coordinates 51.687, -126.234...Screenshot obtained at data/inference_random/2019-11-17_51.687,-126.234_zoom16.png.
# Obtaining screenshot at coordinates 52.382, -124.206...Screenshot obtained at data/inference_random/2019-11-17_52.382,-124.206_zoom16.png.
# Obtaining screenshot at coordinates 51.684, -127.246...Screenshot obtained at data/inference_random/2019-11-17_51.684,-127.246_zoom16.png.
# Discard Lat 50.657 and Long -126.058 as its too close to 50.649 and -126.074
# Discard Lat 50.625 and Long -123.873 as its too close to 50.604 and -123.905
# Discard Lat 50.886 and Long -125.220 as its too close to 50.862 and -125.227
# Obtaining screenshot at coordinates 52.506, -127.419...Screenshot obtained at data/inference_random/2019-11-17_52.506,-127.419_zoom16.png.
# Obtaining screenshot at coordinates 50.975, -127.327...Screenshot obtained at data/inference_random/2019-11-17_50.975,-127.327_zoom16.png.
# Obtaining screenshot at coordinates 51.051, -127.879...Screenshot obtained at data/inference_random/2019-11-17_51.051,-127.879_zoom16.png.
# Obtaining screenshot at coordinates 49.209, -127.716...Screenshot obtained at data/inference_random/2019-11-17_49.209,-127.716_zoom16.png.
# Obtaining screenshot at coordinates 51.957, -123.555...Screenshot obtained at data/inference_random/2019-11-17_51.957,-123.555_zoom16.png.
# Obtaining screenshot at coordinates 52.366, -124.368...Screenshot obtained at data/inference_random/2019-11-17_52.366,-124.368_zoom16.png.
# Discard Lat 50.009 and Long -127.171 as its too close to 50.020 and -127.194
# Discard Lat 50.009 and Long -127.171 as its too close to 50.020 and -127.155
# Discard Lat 48.803 and Long -127.345 as its too close to 48.779 and -127.334
# Obtaining screenshot at coordinates 51.79, -126.433...Screenshot obtained at data/inference_random/2019-11-17_51.79,-126.433_zoom16.png.
# Obtaining screenshot at coordinates 48.925, -126.294...Screenshot obtained at data/inference_random/2019-11-17_48.925,-126.294_zoom16.png.
# Obtaining screenshot at coordinates 52.257, -128.182...Screenshot obtained at data/inference_random/2019-11-17_52.257,-128.182_zoom16.png.
# Discard Lat 49.610 and Long -127.675 as its too close to 49.593 and -127.644
# Obtaining screenshot at coordinates 50.738, -123.796...Screenshot obtained at data/inference_random/2019-11-17_50.738,-123.796_zoom16.png.
# Discard Lat 49.311 and Long -127.329 as its too close to 49.306 and -127.364
# Discard Lat 49.584 and Long -126.687 as its too close to 49.603 and -126.717
# Obtaining screenshot at coordinates 51.819, -124.413...Screenshot obtained at data/inference_random/2019-11-17_51.819,-124.413_zoom16.png.
# Obtaining screenshot at coordinates 50.895, -125.707...Screenshot obtained at data/inference_random/2019-11-17_50.895,-125.707_zoom16.png.
# Discard Lat 48.821 and Long -127.298 as its too close to 48.819 and -127.288
# Discard Lat 50.406 and Long -123.863 as its too close to 50.418 and -123.898
# Discard Lat 49.803 and Long -127.772 as its too close to 49.819 and -127.751
# Obtaining screenshot at coordinates 51.024, -125.781...Screenshot obtained at data/inference_random/2019-11-17_51.024,-125.781_zoom16.png.
# Discard Lat 49.260 and Long -124.392 as its too close to 49.266 and -124.420
# Discard Lat 50.495 and Long -125.733 as its too close to 50.479 and -125.730
# Discard Lat 49.878 and Long -126.068 as its too close to 49.858 and -126.080
# Obtaining screenshot at coordinates 49.045, -125.743...Screenshot obtained at data/inference_random/2019-11-17_49.045,-125.743_zoom16.png.
# Discard Lat 50.574 and Long -123.904 as its too close to 50.549 and -123.921
# Obtaining screenshot at coordinates 51.171, -126.474...Screenshot obtained at data/inference_random/2019-11-17_51.171,-126.474_zoom16.png.
# Discard Lat 50.457 and Long -125.510 as its too close to 50.431 and -125.491
# Obtaining screenshot at coordinates 50.849, -126.943...Screenshot obtained at data/inference_random/2019-11-17_50.849,-126.943_zoom16.png.
# Obtaining screenshot at coordinates 50.617, -124.522...Screenshot obtained at data/inference_random/2019-11-17_50.617,-124.522_zoom16.png.
# Discard Lat 50.752 and Long -123.951 as its too close to 50.746 and -123.931
# Obtaining screenshot at coordinates 52.024, -126.164...Screenshot obtained at data/inference_random/2019-11-17_52.024,-126.164_zoom16.png.
# Obtaining screenshot at coordinates 49.348, -125.649...Screenshot obtained at data/inference_random/2019-11-17_49.348,-125.649_zoom16.png.
# Discard Lat 50.677 and Long -125.905 as its too close to 50.654 and -125.918
# Discard Lat 49.199 and Long -127.560 as its too close to 49.202 and -127.558
# Obtaining screenshot at coordinates 51.156, -124.224...Screenshot obtained at data/inference_random/2019-11-17_51.156,-124.224_zoom16.png.
# Obtaining screenshot at coordinates 52.128, -128.418...Screenshot obtained at data/inference_random/2019-11-17_52.128,-128.418_zoom16.png.
# Discard Lat 49.028 and Long -125.771 as its too close to 49.045 and -125.743
# Obtaining screenshot at coordinates 50.335, -124.39...Screenshot obtained at data/inference_random/2019-11-17_50.335,-124.39_zoom16.png.
# Obtaining screenshot at coordinates 52.743, -128.034...Screenshot obtained at data/inference_random/2019-11-17_52.743,-128.034_zoom16.png.
# Obtaining screenshot at coordinates 49.649, -125.693...Screenshot obtained at data/inference_random/2019-11-17_49.649,-125.693_zoom16.png.
# Discard Lat 49.029 and Long -127.771 as its too close to 49.013 and -127.792
# Discard Lat 50.648 and Long -127.679 as its too close to 50.662 and -127.651
# Obtaining screenshot at coordinates 52.264, -123.785...Screenshot obtained at data/inference_random/2019-11-17_52.264,-123.785_zoom16.png.
# Obtaining screenshot at coordinates 51.271, -127.743...Screenshot obtained at data/inference_random/2019-11-17_51.271,-127.743_zoom16.png.
# Obtaining screenshot at coordinates 48.606, -127.482...Screenshot obtained at data/inference_random/2019-11-17_48.606,-127.482_zoom16.png.
# Discard Lat 49.063 and Long -125.915 as its too close to 49.064 and -125.934
# Discard Lat 48.758 and Long -126.900 as its too close to 48.775 and -126.869
# Obtaining screenshot at coordinates 51.706, -127.604...Screenshot obtained at data/inference_random/2019-11-17_51.706,-127.604_zoom16.png.
# Obtaining screenshot at coordinates 51.138, -125.795...Screenshot obtained at data/inference_random/2019-11-17_51.138,-125.795_zoom16.png.
# Obtaining screenshot at coordinates 51.977, -125.973...Screenshot obtained at data/inference_random/2019-11-17_51.977,-125.973_zoom16.png.
# Discard Lat 50.474 and Long -125.345 as its too close to 50.488 and -125.357
# Discard Lat 49.416 and Long -126.018 as its too close to 49.411 and -125.990
# Discard Lat 49.207 and Long -124.535 as its too close to 49.216 and -124.517
# Discard Lat 49.045 and Long -127.006 as its too close to 49.049 and -127.000
# Obtaining screenshot at coordinates 48.759, -123.703...Screenshot obtained at data/inference_random/2019-11-17_48.759,-123.703_zoom16.png.
# Discard Lat 50.701 and Long -126.761 as its too close to 50.695 and -126.765
# Discard Lat 49.680 and Long -126.889 as its too close to 49.702 and -126.854
# Discard Lat 50.818 and Long -123.811 as its too close to 50.815 and -123.832
# Discard Lat 48.871 and Long -124.047 as its too close to 48.858 and -124.066
# Obtaining screenshot at coordinates 50.457, -125.342...Screenshot obtained at data/inference_random/2019-11-17_50.457,-125.342_zoom16.png.
# Obtaining screenshot at coordinates 49.938, -128.4...Screenshot obtained at data/inference_random/2019-11-17_49.938,-128.4_zoom16.png.
# Obtaining screenshot at coordinates 49.013, -125.218...Screenshot obtained at data/inference_random/2019-11-17_49.013,-125.218_zoom16.png.
# Obtaining screenshot at coordinates 49.992, -124.393...Screenshot obtained at data/inference_random/2019-11-17_49.992,-124.393_zoom16.png.
# Discard Lat 49.121 and Long -126.323 as its too close to 49.145 and -126.349
# Obtaining screenshot at coordinates 52.737, -123.972...Screenshot obtained at data/inference_random/2019-11-17_52.737,-123.972_zoom16.png.
# Discard Lat 50.872 and Long -125.775 as its too close to 50.898 and -125.769
# Discard Lat 49.757 and Long -126.720 as its too close to 49.734 and -126.707
# Obtaining screenshot at coordinates 51.224, -124.569...Screenshot obtained at data/inference_random/2019-11-17_51.224,-124.569_zoom16.png.
# Obtaining screenshot at coordinates 49.27, -127.513...Screenshot obtained at data/inference_random/2019-11-17_49.27,-127.513_zoom16.png.
# Obtaining screenshot at coordinates 52.756, -127.701...Screenshot obtained at data/inference_random/2019-11-17_52.756,-127.701_zoom16.png.
# Obtaining screenshot at coordinates 50.216, -128.372...Screenshot obtained at data/inference_random/2019-11-17_50.216,-128.372_zoom16.png.
# Discard Lat 49.191 and Long -126.301 as its too close to 49.215 and -126.325
# Obtaining screenshot at coordinates 49.062, -124.039...Screenshot obtained at data/inference_random/2019-11-17_49.062,-124.039_zoom16.png.
# Obtaining screenshot at coordinates 49.682, -125.802...Screenshot obtained at data/inference_random/2019-11-17_49.682,-125.802_zoom16.png.
# Obtaining screenshot at coordinates 52.047, -125.992...Screenshot obtained at data/inference_random/2019-11-17_52.047,-125.992_zoom16.png.
# Discard Lat 49.019 and Long -124.722 as its too close to 49.005 and -124.696
# Obtaining screenshot at coordinates 50.476, -128.408...Screenshot obtained at data/inference_random/2019-11-17_50.476,-128.408_zoom16.png.
# Obtaining screenshot at coordinates 51.128, -126.131...Screenshot obtained at data/inference_random/2019-11-17_51.128,-126.131_zoom16.png.
# Obtaining screenshot at coordinates 52.337, -125.122...Screenshot obtained at data/inference_random/2019-11-17_52.337,-125.122_zoom16.png.
# Discard Lat 50.114 and Long -125.582 as its too close to 50.110 and -125.601
# Obtaining screenshot at coordinates 52.342, -125.249...Screenshot obtained at data/inference_random/2019-11-17_52.342,-125.249_zoom16.png.
# Discard Lat 50.535 and Long -123.874 as its too close to 50.530 and -123.908
# Discard Lat 48.855 and Long -127.704 as its too close to 48.869 and -127.697
# Discard Lat 49.241 and Long -126.513 as its too close to 49.259 and -126.488
# Obtaining screenshot at coordinates 50.993, -128.127...Screenshot obtained at data/inference_random/2019-11-17_50.993,-128.127_zoom16.png.
# Obtaining screenshot at coordinates 50.852, -126.031...Screenshot obtained at data/inference_random/2019-11-17_50.852,-126.031_zoom16.png.
# Obtaining screenshot at coordinates 48.964, -127.527...Screenshot obtained at data/inference_random/2019-11-17_48.964,-127.527_zoom16.png.
# Discard Lat 49.754 and Long -126.011 as its too close to 49.755 and -126.037
# Obtaining screenshot at coordinates 50.618, -124.639...Screenshot obtained at data/inference_random/2019-11-17_50.618,-124.639_zoom16.png.
# Obtaining screenshot at coordinates 51.688, -123.895...Screenshot obtained at data/inference_random/2019-11-17_51.688,-123.895_zoom16.png.
# Discard Lat 50.754 and Long -128.497 as its too close to 50.747 and -128.511
# Obtaining screenshot at coordinates 50.125, -125.731...Screenshot obtained at data/inference_random/2019-11-17_50.125,-125.731_zoom16.png.
# Obtaining screenshot at coordinates 52.559, -126.136...Screenshot obtained at data/inference_random/2019-11-17_52.559,-126.136_zoom16.png.
# Discard Lat 50.692 and Long -126.090 as its too close to 50.711 and -126.114
# Discard Lat 50.389 and Long -127.326 as its too close to 50.413 and -127.294
# Obtaining screenshot at coordinates 52.487, -125.214...Screenshot obtained at data/inference_random/2019-11-17_52.487,-125.214_zoom16.png.
# Discard Lat 48.665 and Long -125.486 as its too close to 48.666 and -125.495
# Obtaining screenshot at coordinates 52.651, -124.334...Screenshot obtained at data/inference_random/2019-11-17_52.651,-124.334_zoom16.png.
# Obtaining screenshot at coordinates 49.251, -127.585...Screenshot obtained at data/inference_random/2019-11-17_49.251,-127.585_zoom16.png.
# Obtaining screenshot at coordinates 51.308, -127.546...Screenshot obtained at data/inference_random/2019-11-17_51.308,-127.546_zoom16.png.
# Obtaining screenshot at coordinates 52.629, -127.991...Screenshot obtained at data/inference_random/2019-11-17_52.629,-127.991_zoom16.png.
# Obtaining screenshot at coordinates 51.506, -124.027...Screenshot obtained at data/inference_random/2019-11-17_51.506,-124.027_zoom16.png.
# Obtaining screenshot at coordinates 51.91, -126.581...Screenshot obtained at data/inference_random/2019-11-17_51.91,-126.581_zoom16.png.
# Discard Lat 48.641 and Long -123.746 as its too close to 48.664 and -123.772
# Discard Lat 50.826 and Long -125.537 as its too close to 50.804 and -125.514
# Obtaining screenshot at coordinates 51.732, -123.761...Screenshot obtained at data/inference_random/2019-11-17_51.732,-123.761_zoom16.png.
# Discard Lat 50.010 and Long -124.632 as its too close to 50.000 and -124.614
# Obtaining screenshot at coordinates 52.252, -124.245...Screenshot obtained at data/inference_random/2019-11-17_52.252,-124.245_zoom16.png.
# Obtaining screenshot at coordinates 50.464, -126.133...Screenshot obtained at data/inference_random/2019-11-17_50.464,-126.133_zoom16.png.
# Discard Lat 50.706 and Long -123.700 as its too close to 50.724 and -123.715
# Discard Lat 49.844 and Long -127.889 as its too close to 49.855 and -127.866
# Obtaining screenshot at coordinates 52.774, -124.047...Screenshot obtained at data/inference_random/2019-11-17_52.774,-124.047_zoom16.png.
# Obtaining screenshot at coordinates 52.524, -125.885...Screenshot obtained at data/inference_random/2019-11-17_52.524,-125.885_zoom16.png.
# Discard Lat 50.344 and Long -123.679 as its too close to 50.343 and -123.669
# Discard Lat 50.893 and Long -125.286 as its too close to 50.902 and -125.307
# Obtaining screenshot at coordinates 51.955, -128.16...Screenshot obtained at data/inference_random/2019-11-17_51.955,-128.16_zoom16.png.
# Obtaining screenshot at coordinates 51.445, -126.756...Screenshot obtained at data/inference_random/2019-11-17_51.445,-126.756_zoom16.png.
# Discard Lat 50.976 and Long -124.059 as its too close to 50.963 and -124.032
# Obtaining screenshot at coordinates 49.455, -128.191...Screenshot obtained at data/inference_random/2019-11-17_49.455,-128.191_zoom16.png.
# Obtaining screenshot at coordinates 52.117, -123.847...Screenshot obtained at data/inference_random/2019-11-17_52.117,-123.847_zoom16.png.
# Discard Lat 49.597 and Long -127.445 as its too close to 49.607 and -127.461
# Obtaining screenshot at coordinates 52.208, -127.701...Screenshot obtained at data/inference_random/2019-11-17_52.208,-127.701_zoom16.png.
# Obtaining screenshot at coordinates 50.194, -128.206...Screenshot obtained at data/inference_random/2019-11-17_50.194,-128.206_zoom16.png.
# Discard Lat 49.630 and Long -125.166 as its too close to 49.619 and -125.179
# Obtaining screenshot at coordinates 50.6, -124.012...Screenshot obtained at data/inference_random/2019-11-17_50.6,-124.012_zoom16.png.
# Discard Lat 50.889 and Long -124.901 as its too close to 50.876 and -124.901
# Obtaining screenshot at coordinates 51.301, -128.102...Screenshot obtained at data/inference_random/2019-11-17_51.301,-128.102_zoom16.png.
# Obtaining screenshot at coordinates 50.009, -128.1...Screenshot obtained at data/inference_random/2019-11-17_50.009,-128.1_zoom16.png.
# Obtaining screenshot at coordinates 51.627, -128.481...Screenshot obtained at data/inference_random/2019-11-17_51.627,-128.481_zoom16.png.
# Obtaining screenshot at coordinates 48.596, -127.732...Screenshot obtained at data/inference_random/2019-11-17_48.596,-127.732_zoom16.png.
# Discard Lat 50.938 and Long -124.248 as its too close to 50.951 and -124.272
# Obtaining screenshot at coordinates 52.245, -124.311...Screenshot obtained at data/inference_random/2019-11-17_52.245,-124.311_zoom16.png.
# ...
# Discard Lat 52.722 and Long -126.115 as its too close to 52.729 and -126.129
# Discard Lat 51.594 and Long -127.498 as its too close to 51.585 and -127.493
# Discard Lat 50.379 and Long -124.811 as its too close to 50.391 and -124.796
# Obtaining screenshot at coordinates 51.682, -126.033...Screenshot obtained at data/inference_random/2019-11-17_51.682,-126.033_zoom16.png.
# Discard Lat 49.054 and Long -124.715 as its too close to 49.056 and -124.693
# Obtaining screenshot at coordinates 51.928, -128.379...Screenshot obtained at data/inference_random/2019-11-17_51.928,-128.379_zoom16.png.
# Discard Lat 49.366 and Long -128.125 as its too close to 49.367 and -128.107
# Discard Lat 49.619 and Long -124.603 as its too close to 49.628 and -124.587
# Discard Lat 49.620 and Long -125.731 as its too close to 49.618 and -125.764
# Obtaining screenshot at coordinates 50.958, -125.301...Screenshot obtained at data/inference_random/2019-11-17_50.958,-125.301_zoom16.png.
# Discard Lat 51.994 and Long -124.390 as its too close to 52.010 and -124.381
# Obtaining screenshot at coordinates 52.734, -125.563...Screenshot obtained at data/inference_random/2019-11-17_52.734,-125.563_zoom16.png.
# Discard Lat 49.800 and Long -124.645 as its too close to 49.811 and -124.647
# Discard Lat 50.060 and Long -123.952 as its too close to 50.055 and -123.979
# Obtaining screenshot at coordinates 51.186, -125.978...Screenshot obtained at data/inference_random/2019-11-17_51.186,-125.978_zoom16.png.
# Discard Lat 49.356 and Long -124.915 as its too close to 49.379 and -124.949
# Discard Lat 48.735 and Long -127.938 as its too close to 48.738 and -127.947
# Discard Lat 51.911 and Long -126.713 as its too close to 51.912 and -126.716
# Discard Lat 48.998 and Long -127.046 as its too close to 49.012 and -127.052
# Discard Lat 52.219 and Long -125.285 as its too close to 52.197 and -125.285
# Discard Lat 52.322 and Long -127.125 as its too close to 52.324 and -127.107
# Obtaining screenshot at coordinates 52.62, -128.376...Screenshot obtained at data/inference_random/2019-11-17_52.62,-128.376_zoom16.png.
# Discard Lat 52.400 and Long -124.132 as its too close to 52.389 and -124.107
# Discard Lat 52.622 and Long -126.925 as its too close to 52.601 and -126.950
# Obtaining screenshot at coordinates 48.588, -124.208...Screenshot obtained at data/inference_random/2019-11-17_48.588,-124.208_zoom16.png.
# Obtaining screenshot at coordinates 51.065, -127.54...Screenshot obtained at data/inference_random/2019-11-17_51.065,-127.54_zoom16.png.
# Discard Lat 50.606 and Long -127.565 as its too close to 50.594 and -127.572
# Discard Lat 50.606 and Long -127.565 as its too close to 50.621 and -127.572
# Discard Lat 52.500 and Long -127.741 as its too close to 52.477 and -127.730
# Discard Lat 51.895 and Long -124.580 as its too close to 51.878 and -124.581
# Discard Lat 51.859 and Long -127.705 as its too close to 51.835 and -127.699
# Discard Lat 51.959 and Long -125.014 as its too close to 51.947 and -125.034
# Discard Lat 50.587 and Long -123.971 as its too close to 50.581 and -123.974
# Discard Lat 51.736 and Long -123.775 as its too close to 51.732 and -123.761
# Discard Lat 51.010 and Long -126.092 as its too close to 51.007 and -126.088
# Discard Lat 48.848 and Long -126.190 as its too close to 48.830 and -126.177
# Discard Lat 48.704 and Long -126.756 as its too close to 48.679 and -126.735
# Discard Lat 52.355 and Long -125.158 as its too close to 52.377 and -125.178
# Obtaining screenshot at coordinates 51.469, -127.443...Screenshot obtained at data/inference_random/2019-11-17_51.469,-127.443_zoom16.png.
# Discard Lat 51.869 and Long -125.300 as its too close to 51.865 and -125.305
# Discard Lat 49.760 and Long -123.880 as its too close to 49.769 and -123.892
# Discard Lat 50.319 and Long -125.008 as its too close to 50.341 and -125.034
# Discard Lat 49.259 and Long -124.050 as its too close to 49.255 and -124.036
# Obtaining screenshot at coordinates 51.082, -123.84...Screenshot obtained at data/inference_random/2019-11-17_51.082,-123.84_zoom16.png.
# Discard Lat 51.330 and Long -128.182 as its too close to 51.308 and -128.209
# Discard Lat 52.050 and Long -126.701 as its too close to 52.057 and -126.736
# Discard Lat 50.629 and Long -128.445 as its too close to 50.604 and -128.457
# Discard Lat 50.210 and Long -123.827 as its too close to 50.221 and -123.796
# Discard Lat 51.343 and Long -124.115 as its too close to 51.354 and -124.097
# Discard Lat 52.256 and Long -127.763 as its too close to 52.232 and -127.798
# Discard Lat 51.297 and Long -127.765 as its too close to 51.305 and -127.756
# Discard Lat 51.401 and Long -123.950 as its too close to 51.380 and -123.948
# Discard Lat 49.537 and Long -124.422 as its too close to 49.563 and -124.439
# Discard Lat 52.641 and Long -125.778 as its too close to 52.657 and -125.753
# Discard Lat 50.664 and Long -124.384 as its too close to 50.643 and -124.359
# Obtaining screenshot at coordinates 50.927, -123.609...Screenshot obtained at data/inference_random/2019-11-17_50.927,-123.609_zoom16.png.
# Discard Lat 52.513 and Long -125.744 as its too close to 52.511 and -125.730
# Discard Lat 49.898 and Long -126.405 as its too close to 49.907 and -126.375
# Discard Lat 49.502 and Long -125.155 as its too close to 49.507 and -125.160
# Discard Lat 51.224 and Long -128.186 as its too close to 51.217 and -128.215
# Discard Lat 50.567 and Long -125.709 as its too close to 50.593 and -125.702
# Discard Lat 48.823 and Long -125.440 as its too close to 48.834 and -125.434
# Discard Lat 51.427 and Long -127.307 as its too close to 51.434 and -127.301
# Discard Lat 50.763 and Long -126.278 as its too close to 50.762 and -126.304
# Discard Lat 48.787 and Long -124.765 as its too close to 48.769 and -124.786
# Discard Lat 51.303 and Long -128.140 as its too close to 51.294 and -128.138
# Discard Lat 51.693 and Long -124.679 as its too close to 51.674 and -124.684
# Discard Lat 48.842 and Long -126.892 as its too close to 48.818 and -126.915
# Discard Lat 50.913 and Long -125.102 as its too close to 50.932 and -125.123
# Obtaining screenshot at coordinates 48.724, -125.13...Screenshot obtained at data/inference_random/2019-11-17_48.724,-125.13_zoom16.png.
# Discard Lat 52.737 and Long -126.328 as its too close to 52.758 and -126.337
# Obtaining screenshot at coordinates 50.99, -126.759...Screenshot obtained at data/inference_random/2019-11-17_50.99,-126.759_zoom16.png.
# Discard Lat 49.802 and Long -124.504 as its too close to 49.820 and -124.492
# Discard Lat 52.781 and Long -125.317 as its too close to 52.755 and -125.343
# Discard Lat 51.524 and Long -124.048 as its too close to 51.547 and -124.082
# Discard Lat 48.851 and Long -123.708 as its too close to 48.857 and -123.719
# Discard Lat 51.602 and Long -125.432 as its too close to 51.581 and -125.457
# Discard Lat 51.943 and Long -124.013 as its too close to 51.936 and -124.013
# Discard Lat 48.857 and Long -125.363 as its too close to 48.845 and -125.395
# Discard Lat 49.667 and Long -124.117 as its too close to 49.645 and -124.127
# Discard Lat 50.048 and Long -126.683 as its too close to 50.061 and -126.678
# Discard Lat 50.285 and Long -123.627 as its too close to 50.308 and -123.623
# Obtaining screenshot at coordinates 52.359, -126.251...Screenshot obtained at data/inference_random/2019-11-17_52.359,-126.251_zoom16.png.
# Discard Lat 48.649 and Long -127.388 as its too close to 48.665 and -127.412
# Obtaining screenshot at coordinates 51.329, -124.936...Screenshot obtained at data/inference_random/2019-11-17_51.329,-124.936_zoom16.png.
# Discard Lat 52.317 and Long -125.935 as its too close to 52.290 and -125.944
# Discard Lat 52.348 and Long -125.773 as its too close to 52.333 and -125.751
# Obtaining screenshot at coordinates 49.068, -125.607...Screenshot obtained at data/inference_random/2019-11-17_49.068,-125.607_zoom16.png.
# Discard Lat 52.516 and Long -128.173 as its too close to 52.528 and -128.146
# Discard Lat 51.600 and Long -127.820 as its too close to 51.591 and -127.818
# Discard Lat 48.824 and Long -126.362 as its too close to 48.847 and -126.390
# Obtaining screenshot at coordinates 49.665, -126.322...Screenshot obtained at data/inference_random/2019-11-17_49.665,-126.322_zoom16.png.
# Discard Lat 50.855 and Long -125.016 as its too close to 50.858 and -125.036
# Discard Lat 49.699 and Long -124.595 as its too close to 49.711 and -124.580
# Discard Lat 50.028 and Long -128.128 as its too close to 50.009 and -128.100
# Discard Lat 49.392 and Long -124.543 as its too close to 49.394 and -124.522
# Discard Lat 52.178 and Long -125.509 as its too close to 52.182 and -125.480
# Discard Lat 50.379 and Long -127.576 as its too close to 50.380 and -127.603
# Discard Lat 52.341 and Long -123.763 as its too close to 52.363 and -123.779
# Discard Lat 52.389 and Long -126.562 as its too close to 52.386 and -126.535
# Discard Lat 49.465 and Long -125.916 as its too close to 49.456 and -125.905
# Discard Lat 48.982 and Long -124.350 as its too close to 48.985 and -124.349
# Discard Lat 50.605 and Long -126.892 as its too close to 50.617 and -126.867
# Discard Lat 52.580 and Long -124.942 as its too close to 52.568 and -124.969
# Discard Lat 51.557 and Long -125.558 as its too close to 51.561 and -125.565
# Discard Lat 50.750 and Long -123.815 as its too close to 50.738 and -123.796
# Obtaining screenshot at coordinates 51.477, -124.479...Screenshot obtained at data/inference_random/2019-11-17_51.477,-124.479_zoom16.png.
# Discard Lat 50.505 and Long -125.124 as its too close to 50.513 and -125.157
# Discard Lat 50.723 and Long -125.958 as its too close to 50.709 and -125.959
# Discard Lat 51.027 and Long -124.917 as its too close to 51.043 and -124.900
# Discard Lat 50.654 and Long -127.960 as its too close to 50.653 and -127.982
# Obtaining screenshot at coordinates 52.76, -124.375...Screenshot obtained at data/inference_random/2019-11-17_52.76,-124.375_zoom16.png.
# Discard Lat 51.211 and Long -124.367 as its too close to 51.205 and -124.384
# Discard Lat 52.788 and Long -124.194 as its too close to 52.787 and -124.189
# Discard Lat 51.818 and Long -126.766 as its too close to 51.792 and -126.756
# Discard Lat 50.189 and Long -125.849 as its too close to 50.165 and -125.831
# Discard Lat 51.384 and Long -123.708 as its too close to 51.376 and -123.698
# Discard Lat 49.344 and Long -127.978 as its too close to 49.340 and -127.987
# Discard Lat 52.323 and Long -128.379 as its too close to 52.296 and -128.405
# Discard Lat 52.781 and Long -125.633 as its too close to 52.782 and -125.599
# Discard Lat 51.100 and Long -125.218 as its too close to 51.107 and -125.190
# Discard Lat 48.885 and Long -124.476 as its too close to 48.896 and -124.510
# Discard Lat 49.941 and Long -128.116 as its too close to 49.963 and -128.112
# Discard Lat 49.305 and Long -125.825 as its too close to 49.327 and -125.799
# Discard Lat 49.305 and Long -125.825 as its too close to 49.306 and -125.854
# Discard Lat 48.981 and Long -123.731 as its too close to 48.976 and -123.738
# Discard Lat 48.863 and Long -124.054 as its too close to 48.858 and -124.066
# Obtaining screenshot at coordinates 50.196, -127.044...Screenshot obtained at data/inference_random/2019-11-17_50.196,-127.044_zoom16.png.
# Discard Lat 50.869 and Long -124.702 as its too close to 50.870 and -124.715
# Discard Lat 50.613 and Long -123.627 as its too close to 50.610 and -123.658
# Discard Lat 51.306 and Long -124.985 as its too close to 51.313 and -125.010
# Discard Lat 51.436 and Long -123.601 as its too close to 51.439 and -123.592
# Discard Lat 51.072 and Long -124.658 as its too close to 51.066 and -124.664
# Discard Lat 52.120 and Long -128.391 as its too close to 52.128 and -128.418
# Discard Lat 49.098 and Long -126.517 as its too close to 49.105 and -126.483
# Discard Lat 52.509 and Long -128.472 as its too close to 52.519 and -128.447
# Discard Lat 49.612 and Long -123.596 as its too close to 49.604 and -123.583
# Discard Lat 52.140 and Long -124.076 as its too close to 52.131 and -124.100
# Discard Lat 51.945 and Long -126.784 as its too close to 51.963 and -126.781
# Obtaining screenshot at coordinates 51.336, -124.049...Screenshot obtained at data/inference_random/2019-11-17_51.336,-124.049_zoom16.png.
# Obtaining screenshot at coordinates 50.65, -126.668...Screenshot obtained at data/inference_random/2019-11-17_50.65,-126.668_zoom16.png.
# Discard Lat 49.979 and Long -127.109 as its too close to 49.963 and -127.116
# Discard Lat 49.001 and Long -125.984 as its too close to 49.007 and -126.014
# Discard Lat 51.569 and Long -123.551 as its too close to 51.584 and -123.559
# Discard Lat 51.058 and Long -127.738 as its too close to 51.074 and -127.763
# Discard Lat 48.840 and Long -125.562 as its too close to 48.854 and -125.564
# Discard Lat 49.385 and Long -125.918 as its too close to 49.400 and -125.950
# Discard Lat 48.818 and Long -125.447 as its too close to 48.808 and -125.476
# Obtaining screenshot at coordinates 52.209, -124.307...Screenshot obtained at data/inference_random/2019-11-17_52.209,-124.307_zoom16.png.
# Discard Lat 52.295 and Long -125.620 as its too close to 52.305 and -125.591
# Discard Lat 49.555 and Long -124.905 as its too close to 49.564 and -124.907
# Discard Lat 50.053 and Long -123.870 as its too close to 50.047 and -123.864
# Discard Lat 49.208 and Long -127.248 as its too close to 49.234 and -127.263
# Obtaining screenshot at coordinates 49.99, -127.982...Screenshot obtained at data/inference_random/2019-11-17_49.99,-127.982_zoom16.png.
# Discard Lat 50.418 and Long -128.488 as its too close to 50.407 and -128.487
# Obtaining screenshot at coordinates 52.75, -123.631...Screenshot obtained at data/inference_random/2019-11-17_52.75,-123.631_zoom16.png.
# Discard Lat 51.447 and Long -128.139 as its too close to 51.441 and -128.116
# Discard Lat 50.696 and Long -124.928 as its too close to 50.671 and -124.922
# Discard Lat 50.306 and Long -126.849 as its too close to 50.284 and -126.819
# Obtaining screenshot at coordinates 50.918, -126.361...Screenshot obtained at data/inference_random/2019-11-17_50.918,-126.361_zoom16.png.
# Discard Lat 51.127 and Long -124.904 as its too close to 51.145 and -124.890
# Discard Lat 48.627 and Long -127.765 as its too close to 48.631 and -127.731
# Discard Lat 50.272 and Long -123.737 as its too close to 50.294 and -123.768
# Discard Lat 51.806 and Long -126.720 as its too close to 51.784 and -126.708
# Discard Lat 51.153 and Long -123.920 as its too close to 51.145 and -123.898
# Discard Lat 48.734 and Long -123.539 as its too close to 48.751 and -123.573
# Discard Lat 52.162 and Long -124.735 as its too close to 52.180 and -124.755
# Discard Lat 50.423 and Long -125.827 as its too close to 50.447 and -125.809
# Discard Lat 49.951 and Long -126.056 as its too close to 49.940 and -126.054
# Discard Lat 50.738 and Long -127.582 as its too close to 50.751 and -127.610
# Obtaining screenshot at coordinates 49.606, -124.811...Screenshot obtained at data/inference_random/2019-11-17_49.606,-124.811_zoom16.png.
# Discard Lat 50.388 and Long -126.397 as its too close to 50.361 and -126.380
# Discard Lat 49.322 and Long -123.611 as its too close to 49.312 and -123.590
# Discard Lat 49.206 and Long -128.258 as its too close to 49.186 and -128.254
# Discard Lat 51.564 and Long -127.645 as its too close to 51.580 and -127.654
# Discard Lat 52.550 and Long -124.187 as its too close to 52.545 and -124.199
# Obtaining screenshot at coordinates 52.004, -128.207...Screenshot obtained at data/inference_random/2019-11-17_52.004,-128.207_zoom16.png.
# Discard Lat 48.600 and Long -126.022 as its too close to 48.594 and -126.022
# Discard Lat 50.318 and Long -123.968 as its too close to 50.294 and -123.979
# Discard Lat 49.455 and Long -128.047 as its too close to 49.462 and -128.060
# Discard Lat 52.663 and Long -123.979 as its too close to 52.662 and -123.966
# Obtaining screenshot at coordinates 52.178, -126.479...Screenshot obtained at data/inference_random/2019-11-17_52.178,-126.479_zoom16.png.
# Obtaining screenshot at coordinates 52.543, -123.853...Screenshot obtained at data/inference_random/2019-11-17_52.543,-123.853_zoom16.png.
